# %%
import numpy as np
import scipy as sp
import constants as c
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from simu import Simu

# %%
r = 1.0
Omega_mid = 1.0/r**3
z = np.linspace(0,1,20)
print(z)
# Out:
# [0.         0.05263158 0.10526316 0.15789474 0.21052632 0.26315789
#  0.31578947 0.36842105 0.42105263 0.47368421 0.52631579 0.57894737
#  0.63157895 0.68421053 0.73684211 0.78947368 0.84210526 0.89473684
#  0.94736842 1.        ]

# %%
Omega1 = Omega_mid*(1.-3./4.*(z/r)**2)
Omega2 = 1./(np.sqrt(r**2+z**2)**3)

# %%
plt.figure()
plt.plot(z,Omega1)
plt.plot(z,Omega2)
plt.show()

# %%
alpha = 1.0e-3
h0 = 3.33e-2*c.AU
p = -2.25
q = -0.5
r = 1.*c.AU
h = h0*(r)**((q+3)/2)
z = np.linspace(0,2.0*h,100)

# %%
v_r = -(2.*np.pi*alpha*(h0/c.AU)**2.)*(3.*p+2.*q+6.+0.5*(5.*q+9.)*(z/h)**2.)*(r/c.AU)**(q+0.5)  #T&L2002 Eq. 11
#v_r = -(2.*np.pi*alpha*(h0)**2.)*(3.*p+2.*q+6.+0.5*(5.*q+9.)*(z/h)**2.)*(r)**(q+0.5)  #T&L2002 Eq. 11

# %%
plt.figure()
plt.plot(z/h,v_r)
plt.show()
